# %%
import numpy as np
import matplotlib.pyplot as plt

x=t = np.array([ 0,0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5,5.0,5.5,6]) 
#x1=len(x)
#print(iinfl)
y=infl = np.array([ 0,625,1875,3125,4375,4688,4062, 3437, 2813, 2188,1250,625,0])
y2=oufl=np.array([0,290,1016,1887,2881,3620,3827,3645,3292,2851,1563,938,313])
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(x,y,label="inflow")
ax.plot(x,y2,label="outflow")
ax.legend()
#plot.title(Inflow/outflow hydrograph)
plt.title('HYDROGRAPH')
plt.xlabel("TIME")
plt.ylabel("DISCHARGE")

plt.show()
