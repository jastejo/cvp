# %%
import numpy as np
import matplotlib.pyplot as plt

x=t= np.arange(-6, 108, 6)
print(t)
print(len(t))
#observed flood is indicated by obf
y=obf=np.array([10,10,30,87.5,115.5,102.5,85,71,59,47.50,39,31.5026,
             21.5,17.5,15,12.5,12,12,12])

#plt.plot(t,std)
#plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
fig, ax = plt.subplots(1, figsize=(7, 6))
fig.suptitle("flood hydrograph with base flow seperation",fontsize=20)

# Plot the data
ax.plot(x,y)

# Show the major grid lines with dark grey lines
plt.grid(b=True, which='major', color='green', linestyle='-')

# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='blue', linestyle='-', alpha=0.4)

#plt.show()

N=(np.subtract(90,20))/24
#time to peak=20
#base width of direct runoff=90
#print(N)
#cathnent area in sqkm is indicated byca 
ca=423
N1=0.83*(ca)**0.2
print("N1",N1)
#x = [0, 80]
#y = [8, 13, 21, 30, 31, 44, 50]

# Plot a simple line chart without any feature
#plt.plot(x, y)
#plt.show()

a=np.array([0,80])
b= np.array([10,15])
#a1=np.array([0,6])
#b1=np.array([])
plt.plot (a,b)

plt.show()
#base flow is indicated by bf
bf=np.array([10,10,11,11,12,13,14,14,14,14,14,14,14,14,14,11,11,11,11])
print(len(bf))
#direct runoff ordinates  indicated by dr
dr=np.subtract(obf,bf)
print(dr)
y2=dr=np.array([  0, 0,19,76.5, 103.5, 89.5,71,57,45,33.5,25,17.5026,7.5,3.5,1,1.5,1,1,1])

dr =np.array ([  0, 0,19,76.5, 103.5, 89.5,71,57,45,33.5,25,17.5026,7.5,3.5,1,1.5,1,1,1])     
sum = 0;    
     
#Loop through the array to calculate sum of elements    
for i in range(0, len(dr)):    
   sum = sum + dr[i];    
     
#print("Sum of all the elements(sum of ordinates dr) of an array: " + str(sum))
print("Sum of all the elements(sum of ordinates dr) of an array: ",sum)
sdrf=sum
rfd=(((6*3600*554.0026)/10**6)/423)*100
print("direct runoff volume in cm",rfd)
#unit hydrograph ordinates indicated by uho
y3=uho=dr/rfd
print ("unit hydrograph ordinates",np.round (uho,2))
#from the observed hydrograph knowing basin log , the duration of unit hydrograph is about 6hrs
#print ("uho)
#plt.plot(t,uho)
fig, ax = plt.subplots(1, figsize=(10, 8))
#fig.suptitle('Flood hydrograph and base flow seperation')

# Plot the data
#ax.plot(x,y)

# Show the major grid lines with dark grey lines
plt.grid(b=True, which='major', color='green', linestyle='-')

# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='blue', linestyle='-', alpha=0.4)     
ax.plot(x,y,label="Observed Hydrograph")
ax.plot(x,y2,label="Direct runoff Hydrograph")
ax.plot(x,y3,label="Unit Hydrograph")
plt.title("Flood Hydrograph and unit hydrograph",fontsize=20)
        
#plt.plot(x,y3)
ax.legend()
plt.show()
# Out:
# [ -6   0   6  12  18  24  30  36  42  48  54  60  66  72  78  84  90  96
#  102]
# 19
# N1 2.781929794657984
# 19
# [  0.       0.      19.      76.5    103.5     89.5     71.      57.
#   45.      33.5     25.      17.5026   7.5      3.5      1.       1.5
#    1.       1.       1.    ]
# Sum of all the elements(sum of ordinates dr) of an array:  554.0026
# direct runoff volume in cm 2.828949446808511
# unit hydrograph ordinates [ 0.    0.    6.72 27.04 36.59 31.64 25.1  20.15 15.91 11.84  8.84  6.19
#   2.65  1.24  0.35  0.53  0.35  0.35  0.35]
