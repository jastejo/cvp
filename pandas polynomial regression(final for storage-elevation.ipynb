# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline
dataset=pd.read_csv('stor-elv.csv')
dataset.info
X=dataset.iloc[:,1:2].values
y=dataset.iloc[:,2].values
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,y)
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
X_poly=poly_reg.fit_transform(X)
poly_reg.fit(X_poly,y)
lin_reg2=LinearRegression()
lin_reg2.fit(X_poly,y)
X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape((len(X_grid),1))
#plt.scatter(X,y,color='red')

plt.subplot(1,2,1)
plt.plot(X,lin_reg2.predict(poly_reg.fit_transform(X)),color='blue')
plt.title('Storage-Elevation')
plt.xlabel('Storage')

plt.ylabel('Elevation')        
           
plt.show() 
print(lin_reg.predict(np. array([ [140] ]) ))
print(lin_reg2.predict( poly_reg.fit_transform(np.array([ [15] ]) )))
##import numpy as np
import matplotlib.pyplot as plt
inf=np.array([0,50,280,610,1290,1900,2130,1900,1600,1440,1200,1060,780,500.370,220,130])
t=np.array([ 0,6,12,18,24,30,36,42,48,51,60,66,78,90,102,114]) 
t1=6*0.003600
volinf = np.zeros_like(inf)
for i in range(1,16):
    volinf[i] =(((inf [i-1] +inf[i])/2 ))*t1
print("Volume of inflow",volinf) 
y=res_el=np.array([140,141,142,143,144,145,146]) 
#spillway crest level =140ft
x=oufl=([0,170,482,883,1360,1905,2500])
plt.subplot(1,3,2)
plt.title("------")
plt.xlabel("outflow")
plt.ylabel("reservoir elevation")

plt.plot(x, y)
# Out:
# [144.37125042]
# [140.98367069]
# Volume of inflow [ 0.        0.54      3.564     9.612    20.52     34.452    43.524
#  43.524    37.8      32.832    28.512    24.408    19.872    13.827996
#   7.779996  3.78    ]
